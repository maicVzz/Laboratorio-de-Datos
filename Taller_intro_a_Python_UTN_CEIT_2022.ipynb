# %% [markdown]
# <a href="https://colab.research.google.com/github/maicVzz/Laboratorio-de-Datos/blob/main/Taller_intro_a_Python_UTN_CEIT_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Taller intro a Python UTN - CEIT
# **Profesor**: Ignacio Guardines
# <br>
# **telegram | twitter** :@nacho_java

# %% [markdown]
# Grupo de telegran: https://t.me/+FY6Wd9bnzcI4MzMx

# %% [markdown]
# ![logoutnwhite.png](data:image/png;base64,...)

# %% [markdown]
# ## Consideraciones previas
# * Edad mínima, máxima, tiempo de aprendizaje, es dificil, es facil

# %% [markdown]
# ## Que es y para que programar
# Programar es el arte por el cual y por medio de un lenguaje de programacion se le indica a las computadoras que hagan tareas determinadas, tareas que la computadora pueda realizar.
# Cada dia hay mas dispositivos que necesitan ser programados.
# Un aeronave, los cohetes de spaceX, un auto con piloto automatico, un robot conversacional, un satelite, los robot de trading, los visores de precios. En el caso de un auto se puede junto con sensores, utilizar para diagnosticar si los niveles estan bien.
# Es una necesidad y hay mas demanda de gente que programe que personas programando, hay mucho por hacer.

# %% [markdown]
# ## ¿Que es un algoritmo?
#
# Un algoritmo es un conjunto de instrucciones ordenadas para obtener un resultado especifico.
# #### Ejemplos de algoritmos:
# ##### El manual que viene en un mueble para armar. donde explica paso a paso las cosas que se deben hacer para que el mueble quede listo para usar.
#  - 1) Enumeración de las piezas que componen el mueble.
#  - 2) Listado de los materiales necesarios y sus dimensiones.
#  - 3) Explicación paso a paso para la construcción de cada pieza, cada medida,  cada corte y cada perforación, además de cual plantilla utilizar.
#  - 4) Unión de las piezas con explicación de cuál tornillo usar en cada caso.
#  - 5) Armado completo del mueble hasta terminar.
#
#
#  #### Como reemplazar una lampara quemada.
#  - 1) Tener la/s piezas a reemplazar.
#  - 2) Cortar el suministro electrico.
#  - 3) Quitar la lampara quemada.
#  - 4) Colocar la lampara nueva.
#  - 5) Activar el suministro electrico.
#  - 6) Prender el interruptor y comprobar el correcto funcionamiento.
#
#
# A continuacion se presenta el algoritmo simplificado de como hacer una pizza por medio de un diagrama de flujo.
#
# ![image.png](data:image/png;base64,...)
#
# https://lucid.app/es-LA/users/login#/login

# %% [markdown]
# ## Algunas consideraciones sobre la computadora
# ### Partes externas
#
# - De salida
#     - Monitor. También llamado pantalla, es un componente esencial; pues de alguna manera es la ventana del usuario para ejecutar y observar las actividades necesarias.
#     - Parlantes.
#     - Impresora.
#
#
# - De entrada
#     - Teclado. Este es un componente de entrada de información.
#     - Mouse.
#     - lapiz optico
#     - Cámara Web.
#     - Micrófono.
#     - Escáner
#     - Lector de código de barras
#     - Sensor de huella digital
#
#
# - De entrada - Salida
#   - Puertos y conectores.
#   - Disco rigido.
#   - Tarjeta de Red.
#   - Lecto/grabadora de DVD.
#   - Memoria flash.
#
# ### Partes internas
#
# - Procesador (CPU)
# - Placa Madre
# - Memoria RAM
# - Memoria ROM
# - Discos
# - Placa Base o placa Madre o Motherboard
# - Tarjetas (Video, sonido, red)
#
# ### El Vinculo entre ambas partes
# - BIOS (sistema basico de entrada y salida)
# - El sistema operativo
#   - Windows
#   - Linux
#   - MacOS

# %% [markdown]
# ## Python, ¿Que es? como funciona, otros lenguajes de programación historia, ¿Es para cualquiera?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Python es un lenguaje de programación interpretado cuya filosofía hace hincapié en la legibilidad de su código. Se trata de un lenguaje de programación multiparadigma, ya que soporta parcialmente la orientación a objetos, programación imperativa y, en menor medida, programación funcional. Es un lenguaje interpretado, dinámico y multiplataforma.

# %% [markdown]
# ## Que es colab, repl.it, jupyter notebook, spyder entre otros

# %% [markdown]
# - Colaboratory:
#  también llamado "Colab", te permite ejecutar y programar en Python en tu navegador con las siguientes ventajas: No requiere configuración. Da acceso gratuito a GPUs. Permite compartir contenido fácilmente.
# - repl.it:
#   un entorno de desarrollo online como colab.
#
# - Jupyter notebook:
# Jupyter Notebook (anteriormente IPython Notebooks) es un entorno informático interactivo basado en la web para crear documentos de Jupyter notebook. El término "notebook" puede hacer referencia coloquialmente a muchas entidades diferentes, principalmente la aplicación web Jupyter, el servidor web Jupyter Python o el formato de documento Jupyter según el contexto. Un documento de Jupyter Notebook es un documento JSON, que sigue un esquema versionado y que contiene una lista ordenada de celdas de entrada/salida que pueden contener código, texto (usando Markdown), matemáticas, gráficos y texto enriquecidos, generalmente terminado con la extensión ".ipynb".
#
# - Spyder:
#  Spyder es un entorno de desarrollo integrado multiplataforma de código abierto para programación científica en el lenguaje Python.
#
# - pyCharm:
# PyCharm es un entorno de desarrollo integrado que se utiliza en programación informática, específicamente para el lenguaje Python. Está desarrollado por la empresa checa JetBrains.

# %%
nombre = "Ignacio"
print(nombre)
# Out:
# Ignacio

# %%
# snake_case
# camelCase
#PascalCase
# Out:
# 	primera linea
#
#
#
# asegunda linea

# %%
print("Hola gente!")
# Out:
# Hola gente!

# %%
print("Hola Mundo!")
# Out:
# Hola Mundo!

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %% [markdown]
# - https://repl.it/languages/python3
# - https://colab.research.google.com/
# - https://jupyter.org/try
# - https://www.anaconda.com/products/individual

# %% [markdown]
# ## ¿Que son las variables?

# %% [markdown]
# Ingreso de valores por teclado por medio de la funcion input()

# %%
precio_come = "3"

# %%
#int(str)
#float(string)
#str()
int(precio_come)  + 1
# Out:
# 4

# %%
var1, var2= 1, 2

print(var1, var2)
# Out:
# 1 2

# %%
nombre = input("ingresa tu nombre: ")
print("Buen dia", nombre, "!")
# Out:
# ingresa tu nombre: Ignacio
# Buen dia Ignacio !

# %% [markdown]
# ## Tipos de datos basicos
# ** Numeros
# * Numeros enteros
# * Numeros flotantes
# ** Cadena de caracteres o Strings (palabras)
# ** Valores de verdad (Booleanos)

# %%
market_id, ord_type, side = "BYMA", "limit", "buy"
ord_type = "market"
side = input("side")

# %%
f"hola es dia {29}"
# Out:
# 'hola es dia 29'

# %%
mensaje = "orden a {market_id} , tipo de orden {ord_type}, del lado de {side}"
print( mensaje )
# Out:
# orden a {market_id} , tipo de orden {ord_type}, del lado de {side}

# %%
market_id = "ROFEX"
ord_type = "limit"
side = "buy"


orderQty, side = "Market", "Sell"

#Ejercicio: reemplazar los valores de ordType y side por Market y sell respectivamente
#Ejercicio 2, hacer lo mismo pero usando asignacion multiple.

variable1, variable2 = 1, 2 # asdasd


price = 10.50
order_qty = 1_000_000

#Ejercicio: cambiar el precio y orderQty por otros valores de su preferencia.
#Ejercicio: declarar y definir una variable account con un numero entero que represente
# un numero de cuenta.

print(f"se va a colocar una orden en {market_id} por un precio de {price} y por una cantidad {order_qty}")
# Out:
# se va a colocar una orden en ROFEX por un precio de 10.5 y por una cantidad 1000000

# %% [markdown]
# Ejercicio:
# price =
# order_qty = 10000
# crear una variable que represente un nombre usuario
# y otra mas que sea el id del usuario

# %%
var = "hola " + str(1)
print(var)
# Out:
# hola 1

# %%
numero_1= 1 
var_2 = f"hola {numero_1}" 
print(var_2)
# Out:
# hola 1

# %% [markdown]
# ## Camel Case minusculaMayusculaMayuscula precioCompra
# ## Pascal Case MayusculaMayuscula PrecioCompra
# ## Snake Case minuscula_minuscula precio_compra

# %% [markdown]
# ##Palabras reservadas

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def = 1
# Out:
#   File "<ipython-input-22-09f57f03a914>", line 1
#     def = 1
#         ^
# SyntaxError: invalid syntax

# %%
variable1, variable2 = "Hola", 2

# %%
print(variable2)
# Out:
# 2

# %% [markdown]
# ## Operador Asignacion primera parte

# %%
variable = "valor"
variable
# Out:
# 'valor'

# %% [markdown]
# ## Primer programa en python
# * Uso de la función print()
# * concatenar palabras
# * Se veran otras funciones para manipular Cadenas de caracteres

# %%
print("hola", "mundo")

palabra = "hola" + "Mundo"
palabra
# Out:
# hola mundo
# 'holaMundo'

# %% [markdown]
# #### Expresiones
#
# Una expresión es una porción de código que produce o calcula un valor (resultado).
#
# Un valor es una expresión (de hecho es la expresión más sencilla). Por ejemplo el resultado de la expresión 1 es precisamente el número 1.
# Una variable es una expresión, y el valor que produce es el que tiene asociado
# la suma 1 + 2 es una expresion cuyo valor devuelve 3

# %% [markdown]
# ### Imprimiendo una variable

# %%
saludo = "hola"
saludo
# Out:
# 'hola'

# %%
help (print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ## Operadores y Operaciones

# %% [markdown]
# #### Operadores y operaciones aritméticas
#
# *   "+"  Suma (10+5 tendría como resultado 15)
# *   "-"  Resta (10-5 sería 5)
# *   "*"  Multiplicación (20 * 4 daría 80)
# *   "/"  División (21/5 tendría como resultado 4.2)
# *   "%"  Resto de la división, también conocido como "módulo"  (21%5 sería 1)
# *   **   Potencia (un número entero elevado a otro: 12**2 sería 144)
# *   //   División entera (sin decimales) (22//5 sería 4, y 22.0//5.0 sería 4.0)

# %%
price
# Out:
# 107.25

# %%
x = 1
x = x - 1
x = x + 1
# Out:
# 2

# %%
11 // 2
# Out:
# 5

# %%
4 ** 0.5
# Out:
# 2.0

# %%
# esto es un comentario
# Out:
# 'esto no'

# %%
precio = 108
precio <= 108
# Out:
# True

# %%
precio != 108
# Out:
# False

# %%
or and not

# %%
# False or True => True
# False or False => False


# True and True
not es_miercoles

# %%
es_miercoles = False
es_horario_mercado = False
precio = 1230
precio_compra = 1200
precio == precio_compra
izq = 10 
der = 4
es_fin_de_semana = True
ni_fin_de_semana_ni_miercoles = not (es_miercoles or es_fin_de_semana)
puedo_operar = es_miercoles or es_fin_de_semana
#print(puedo_operar )
not False
# Out:
# True

# %%
#x = x * 3
4 ** 0.5
# Out:
# 2.0

# %% [markdown]
# #### Operadores y operaciones lógicas
#
# *   or: Devuelve un valor de verdad, es verdadero si al menos uno es verdadero
# *   and: Devuelve un valor de verdad, es verdadero si ambas variables son  verdaderas
# *   not: Devuelve un valor de verdad, invierte el valor de verdad de la variable a la que afecta.

# %%
esHorarioMercado = False
esLunes = False
esLunes or esHorarioMercado
# Out:
# False

# %%
tengoMargen = True
compreDolarFuturo = False
tengoMargen and not compreDolarFuturo
# Out:
# True

# %%
precio_alarma = 20
precio_spot  = 20
precio_alarma >= precio_spot
# Out:
# True

# %%
dia = "lunes"
hora = 18

dia == "lunes" and hora > 17
# Out:
# True

# %%
dia = "martes"
hora = 19
#True or False = True
# False or True = True
False and True
# Out:
# False

# %%
(dia == "lunes" or hora > 11) or (dia == "sabado")
# Out:
# True

# %%
es_horario_mercado = True
dispongo_dinero = False
es_fin_de_semana = False

(es_horario_mercado and dispongo_dinero) or (es_fin_de_semana and dispongo_dinero)

(es_horario_mercado or es_fin_de_semana) and dispongo_dinero
# Out:
# False

# %%
not es_horario_mercado and not es_fin_de_semana
# Out:
# True

# %%
not (es_horario_mercado and es_fin_de_semana)
# Out:
# True

# %% [markdown]
# #### Operadores relacionales (de comparación)
#
# Los operadores relacionales nos permiten comparar expresiones de tipos compatibles, devolviendo un resultado de tipo lógico: la comparación es verdadera o falsa. Por ejemplo, la expresión (3 + 4) > 12 sería falsa, ya que 7 es menor que 12. por tanto puedo comparar obteniendo un valor resultante a dicha comparacion
#
# *  ">" Mayor estricto, devuelve un valor de verdad resultado si es o no mayor el contenido de la primer variable respecto de la segunda, devuelve True si es asi False caso contrario.
# *  "<" Menor estricto, devuelve un valor de verdad resultado si es o no menor el contenido de la primer variable respecto de la segunda, devuelve True si es asi False caso contrario.
# *  ">=" Mayor o igual, similar al mayor estricto, agrega la igualdad.
# *  "<=" Mayor o igual, similar al menor estricto, agrega la igualdad.
# *  "==" Igualdad, devuelve True si ambas variables son iguales, False caso contrario.
# *  "!=" Distinto, devuelve True si ambas variables son distinteas, False caso contrario.

# %% [markdown]
# #### Operadores de asignación
#
#
# ![image.png](data:image/png;base64,...)

# %%
actualPrice = 107.25
futurePrice = 108.25
#1 != 2

actualPrice < futurePrice
futurePrice
# Out:
# 108.25

# %%
#DolarBCRAA3500 = 78.0883
#DODic20 = 84

# %%
x = x + 1

# %%
type(actualPrice)
# Out:
# str

# %%
contador = 1

# %%
contador = contador + 1

# %%
print(contador)
# Out:
# 7

# %%
totalAcumulado = 0
totalAcumulado +=  1000
totalAcumulado +=  2000
totalAcumulado += (-2000 )

# %%
totalAcumulado
# Out:
# 1000

# %%
# Ejercicio: dada una compra de un contrato de futuro por un precio de 12500$ representada en una variable 
# RFX20 acorde incrementar el valor que representa
# sumandole 0,15% del total en concepto de comision por compra del contrato.

# %%
# Ejercicio: dada una variable contratoRofex20 por un valor de 10000$, decrementar su valor por una baja en los precios por un 0,23 del total%

# %% [markdown]
# ## Strings
# Los Strings o cadena de caracteres, o listas de caracteres, son otro tipo de dato de python para crear un string simplmeente se debe poner el contenido o valor entre comillas dobles o simples
#
# - "String valido con comillas dobles"
# - 'String valido con comillas simples'
#
# - "   'String con ambas'String valido con comillas dobles y simples"
# - 'String invalido"

# %% [markdown]
# ## Metodos de los strings
#
# - capitalize()	Convierte el primer caracter en mayuscula
# - count()	retorna la cantidad de veces que un caracter dado se encuentra en el string.
# -find()	Busca un determinado string y devuelve la posicion donde se encuentra.
# -index()	Busca un determinado string y devuelve la posicion donde se encuentra.
#
# - isdigit()	Retorna True if all characters in the string are digits
# - islower()	Retorna True if all characters in the string are lower case
# - join()	Convierte los elementos de un iterable en un String.
# - lower()	Convierte los caracteres de un string a minusculas.
# - replace()	Retorna un string donde un valor especifico es reemplazado por otro.
# - split()	Separa el string en un determinado separador, y retorna una lista
# - title()	Convierte la primera letra de cada palabra en un string.
# - upper()	Convierte a mayusculas todas las letras de una palabra.

# %% [markdown]
# ## funcion input()
# La funcion input permite al usuario escribir y pasar al programa valores, estos valores recibidos son del tipo string.

# %% [markdown]
# ### Conversión entre tipos de datos

# %% [markdown]
# - String a int
# - int a String
# - String a float
# - float a string
# - boolean a String
# - String a boolean.

# %% [markdown]
# ##Colecciones de datos
# ### Listas
# Son mutables, nos permiten modelar conjuntos de elementos, pueden ser del mismo o diferente tipo.
# Se acceden por indice por lo que tienen un orden y cuentan con varias operaciones propias.
# <br>
# Los string son una lista de caracteres.
# <br>
# En las listas la primer posicion es el 0

# %% [markdown]
# ##Funcion range()
# La función range() devuelve una secuencia de números, comenzando desde 0 de forma predeterminada, se incrementa en 1 (de forma predeterminada) y se detiene antes de un número especificado.

# %% [markdown]
# ## slicing (Intervalos)
# [ desde : hasta : paso ]
#
#
# - El desde siempre es inclusive
# - El hasta es siempre exclusive
# - [:] todo
# - [::-1] orden inverso

# %% [markdown]
# ## Métodos de listas
#
# - index(n) (devuelve el orden dentro de la lista del elemento "n")
# - count (cuenta la cantidad de elementos)
# - sort(reverse=False)
# - append (agrega un valor al final)
# - extend (agregaega una lista entera de valores)
# - insert(x, "n") (inserta el elemento "n" en la posicion "x")
# - pop ("n") "saca" el elemento "n" y me lo devuelve como return
# - reverse (invierte el orden dado)
# - clear() (borra los elementos de la lista)

# %% [markdown]
# ## Tuplas
#
# Son similares a las listas con la unica diferencia que no se pueden modificar, son inmutables, se usan como conjuntos y tambien para modelar informacion.

# %% [markdown]
# ## Librerias de tiempos (Fechas e instantes)
# Sublibrerias
#
# datetime
# time
# timedelta
# date

# %% [markdown]
# ## Bloque de código
#
# Un bloque de código es un grupo de sentencias relacionadas por una identación. A diferencia de otros lenguajes como JAVA o C, en los que se usan los caracteres {} para definir un bloque de código, en Python se usa la indentación o sangria.
#
# ### Identacion
# La sangria o indentación consiste en mover un bloque de texto hacia la derecha insertando espacios o tabuladores al principio de la línea, dejando un margen a la izquierda
# ### Identación
# En un lenguaje informático, la identación es lo que la sangría al lenguaje humano escrito (a nivel formal). Así como para el lenguaje formal, cuando uno redacta una carta, debe respetar ciertas sangrías, los lenguajes informáticos, requieren una identación.

# %% [markdown]
# ## Funciones
#
# Una función es un bloque de código con un nombre asociado, que recibe cero, uno o más argumentos como entrada, sigue una secuencia de sentencias, la cuales ejecuta una operación deseada y devuelve un valor y/o realiza una tarea, este bloque puede ser llamados cuando se necesite.
#
# El uso de funciones es un componente muy importante del paradigma de la programación llamada estructurada, y tiene varias ventajas:
#
# - modularización: permite segmentar un programa complejo en una serie de partes o módulos más simples, facilitando así la programación y el depurado.
# - reutilización: permite reutilizar una misma función en distintos programas/ distintas partes del programa.
#
# Python dispone de una serie de funciones integradas al lenguaje, y también permite crear funciones definidas por el usuario para ser usadas en su propios programas.
#
# <br>
#
# se utiliza una palabra especial "def" para crear una función definidas por el usuario, seguida por el nombre de la funcion y la lista de parametros.

# %% [markdown]
# ### Diferencia entre definir y aplicar (usar)

# %% [markdown]
# ### Sin parametros/argumento y sin retornar nada
#
#
# definicion y uso
# firma de la funcion nombre_funcion(Area de parametros/argumentos):

# %%
def mostrar_terminos_y_condiciones():
  """ 
  Esta es la documentacion ...
  de la funcion que imprime simplemente por pantalla
  params: none
  return: none
  """ 
  print("los termnos y condiones...")




def fijar_valor_venta(precio=100, umbral=1):
  #print(f"el valor de venta es  {precio * umbral}")
  return precio * umbral

# %% [markdown]
# ### Con un parametro sin retorno

# %%
def saludar(nombre):
  print(f"hola {nombre}!")

# %% [markdown]
# ### Con parametros y retorno

# %%
def sumar(x1, x2):
  """
  La funcion sumar recibe dos numeros y devuelve la suma de ambos
  parametros: x1, x2 deben ser numericos
  retorna: la suma de x1 y x2
  """
  return x1 + x2

# %% [markdown]
# ## Libreria random - números pseudo-aleatorios
# La biblioteca random contiene una serie de funciones relacionadas con los valores aleatorios. El listado completo de funciones de esta biblioteca se describe en el manual de Python.

# %%
###primero debemos importar la libreria
import random as rd # podemos agregarle un alias

rd.randrange(10)

# %%
# numero entero aleatorio entre 0 y 10

import random

print(random.randint(0,10 ))

# %% [markdown]
# ### Elegir uno en una secuencia

# %%
import random

print(random.choice((14, 15, 20, 150)))
# Out:
# 150

# %% [markdown]
# ## Estructuras de control condicionales

# %% [markdown]
# ### Control de Flujo condicional
# * if
# * elif
# * else

# %% [markdown]
# ### Sentencia if
# La sentencia **if expresion**, significa, Si se cumple la expresión condicional se ejecuta el bloque de sentencias seguidas.

# %% [markdown]
# ### Sentencia elif
#
# La sentencia **elif expresion**, significa, De lo contrario Si se cumple la expresión condicional se ejecuta el bloque de sentencias seguidas.

# %% [markdown]
# ### Sentencia else
#
# La sentencia **else**, significa, De lo contrario se cumple sin evaluar ninguna expresión condicional y ejecuta el bloque de sentencias seguidas. Es opcional

# %%
#dia = "martes"
print("camino")

tengo_sed= True
tengo_plata = True
if tengo_sed:
  print("tomo agua")
elif tengo_plata:
  print("me compro una coca")
else:
  pass

print("camino")

# %% [markdown]
# ##Estructuras de control iterativas

# %% [markdown]
# ### Ciclo definidos **for**

# %%
print("Empiezo")

for x in ["Lunes","Martes"]:
    print(f"Hola {x}")

print("Termino")

# %% [markdown]
# ###Ciclo while

# %%
i = 0
while i < 5:
  ##ejecuto codigo
  print(i)
  print("ejecuto orden ddd")
  i +=1
